# %% [markdown]
# # Import the main libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import joblib
import missingno as msno

# Sklearn
from sklearn.model_selection import train_test_split, cross_val_predict, cross_val_score
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder, OrdinalEncoder, PolynomialFeatures
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn_features.transformers import DataFrameSelector

from sklearn.linear_model import LinearRegression, SGDRegressor, Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_squared_error
from sklearn.neighbors import KNeighborsRegressor

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

import xgboost
# Out:
# The kernel failed to start as 'has_suggestion' could not be imported from 'c:\Users\Salma\anaconda3\lib\site-packages\prompt_toolkit\filters\__init__.py'.
#
# Click <a href='https://aka.ms/kernelFailuresModuleImportErrFromFile'>here</a> for more info.

# %% [markdown]
# # Load the DataSet and look at the big picture

# %%
# Read the csv file using pandas
path_file = os.path.join(os.getcwd(),'housing.csv')
df_housing = pd.read_csv(path_file)
# Show the head of the DF
df_housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
# Check some info about the DataSet (see Nulls and DataTypes)
df_housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
# Show some statistics about the DataSet
df_housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
# Check the nulls
df_housing.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
# check nulls using (missingno) library -- take care of the sum of above each bar
msno.matrix(df_housing)
# Out:
# <AxesSubplot:>

# %% [markdown]
# * `Comment: It seems that DateSet contains 20640 instances and only 207 null values in total_bedrooms feature, and also all datatypes are float64 as they are continuous numerical features except the Ocean_proximity column which is nominal categorical feature.`

# %% [markdown]
# # `Exploratory Data Analysis`

# %% [markdown]
# ## `Univariate Visualization`

# %%
# Check the distribution of Ocean_proximity feature in DataSet
Ocean_Values = df_housing['ocean_proximity']
replicates = df_housing['ocean_proximity'].value_counts()
# Plotting
plt.figure(figsize=(10,6))
sns.countplot(x='ocean_proximity', data=df_housing, order=replicates.index)
plt.title('Countplot of "Ocean_Proximity" feature in dataset', fontsize=14, c='k')
plt.xlabel('Ocean Proximity', fontsize=14, c='k')
plt.ylabel('Counts', fontsize=14, c='k')
for i in range (len(replicates)):
    each_count = replicates.values[i]
    each_text = f'{each_count*100/len(df_housing):.3f} %'
    plt.text(x= i, y= each_count+100, s=each_text, ha='center', c='b')
plt.show()

# %%
# Replace the (<1H Ocean) to 1H Ocean -- will cause errors in deployment
df_housing['ocean_proximity'].replace('<1H OCEAN', '1H OCEAN', inplace=True)

# %%
# Histogram distribution of Numerical features in datasets
df_housing.hist(bins=50, figsize=(20,10))
plt.show()

# %%
# Scatterplot with important feature (median_income) with the target (median_house_value)
plt.figure(figsize=(10,6))
plt.scatter(x='median_income', y='median_house_value', data=df_housing, alpha=0.1)
plt.title("Distribution of median income with house value", c='k', fontsize=14)
plt.xlabel("Median Income", c='k', fontsize=14)
plt.ylabel("Median House Value", c='k', fontsize=14)
plt.show()

# %%
# Try for (median_house_vaue) to convert it into chunks (bins)
# Cut this numerical feature to categorical one
# EX: For the following examlpe -- any value between range (0 - 100k) will be the same category like histogram
house_value_bins = pd.cut(df_housing['median_house_value'], bins=[-np.inf, 100000, 200000, 300000, 400000, 500000, np.inf], labels=['0-100k', '100k-200k', '200k-300k', '300k-400k', '400k-500k', '600k<'])
plt.figure(figsize=(10,6))
sns.countplot(x=house_value_bins)
plt.title('CountPlot of house value bins in the DataSet', fontsize=14, c='k')
plt.xlabel('House Value Bins', fontsize=14, c='k')
plt.ylabel('Counts', fontsize=14, c='k')
plt.show()

# %%
# Let's try the same above code for median_income, I think it is very important feature
income_bins = pd.cut(df_housing['median_income'], bins=[-np.inf, 1.5, 3, 4.5, 6, np.inf], labels=['0-1.5', '1.5-3', '3-4.5', '4.5-6', '6<'])

# CountPlot for the above chunks
plt.figure(figsize=(10, 6))
sns.countplot(x=income_bins)
plt.title('CountPlot of Income bins in DataSet', fontsize=14, c='k')
plt.xlabel('Median Income', fontsize=14, c='k')
plt.ylabel('Counts', fontsize=14, c='k')
plt.show()

# %% [markdown]
# * > `Comment: It seems that the (<1H ocean) is about the half of the dataset the data is biased to this category, someone can think to split the data according to this column using (startified) method if we found that this column is very important, we will discuss that later, Also, it seems that the Distribution of most of features are right skewed (exponential distribution) and it is known that the best distribution to be passed to the model is Normal Distribution, we will go further with these features to know how to deal with these skewed distrbution later, Also the majority of house_value is between (100k-200k), Also the majority of median_income is between (3-4.5), someone can change his mind and split the dataset using (startified) method according to the most important feature as I think till now which is (median income) but use (income bins) as the stratified`

# %% [markdown]
# ## `Bivariate Visualization`

# %%
# Scatter plot with (median_income) and (median_house_value) at each (ocean_proximity)
sns.relplot(kind='scatter', x='median_income', y='median_house_value', data=df_housing, col='ocean_proximity', col_wrap=3)
plt.show()

# %%
# Check the boxplot of the (median_income) at different categories of (ocean_proximity)
plt.figure(figsize=(10, 6))
sns.boxplot(y='median_income', x='ocean_proximity', data=df_housing)
plt.title('BoxPlot of Median Income at different "ocean Proximity" category', fontsize=14, c='k')
plt.xlabel('Ocean Proximity', fontsize=14, c='k')
plt.ylabel('Median Income', fontsize=14, c='k')
plt.show()

# %%
# Check the boxplot for (median_house_value) at different categories of (ocean_proximity)
plt.figure(figsize=(10, 6))
sns.boxplot(y='median_house_value', x='ocean_proximity', data=df_housing)
plt.title('BoxPlot of Median House Value at different "ocean Proximity" category', fontsize=14, c='k')
plt.xlabel('Ocean Proximity', fontsize=14, c='k')
plt.ylabel('Median House Value', fontsize=14, c='k')
plt.show()

# %% [markdown]
# * > `Comment: It seems the Distribution of Median_Income is almost the same at ocean_proximity categories, also, it seems that the INLAND median_income and median_house_value is less than other categories and it makes sense`

# %% [markdown]
# ## `Multivariate Visualization`

# %%
# Scatterplot for (longetude and latitude), and add population as size of point, and the color as (median_house_value)
plt.figure(figsize=(12, 6))
sc = plt.scatter(x='longitude', y='latitude', data=df_housing, s=df_housing['population']/100, c=df_housing['median_house_value'],
            cmap=plt.get_cmap('jet'), label='Population')
plt.colorbar(sc)
plt.title("Longetude Vs. Latitude", fontsize=14, c='k')
plt.xlabel("Longetude", fontsize=14, c='k')
plt.ylabel("Latitude", fontsize=14, c='k')
plt.legend()
plt.show()

# %% [markdown]
# ## `Check the Correlation between Features and Target`

# %%
# using pearson correlation
df_housing.corr()['median_house_value'].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.688075
# total_rooms           0.134153
# housing_median_age    0.105623
# households            0.065843
# total_bedrooms        0.049686
# population           -0.024650
# longitude            -0.045967
# latitude             -0.144160
# Name: median_house_value, dtype: float64

# %%
# you can show this as heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(df_housing.corr(), annot=True, cmap='Blues', fmt='.2f')
plt.show()

# %% [markdown]
# * > `Comment: It seems that the most correlated feature with target is (median_income) as I predict that, and feature like (households & population) are less correlated`

# %% [markdown]
# # `Feature Engineering`
# #### `Try to add some features, thinking that it will be more useful and more correlated to the target`

# %%
# Try to make some Feature Engineering --> Feature Extraction --> Add the new column to the main DF
df_housing['rooms_per_households']=df_housing['total_rooms'] / df_housing['households']
df_housing['bedrooms_per_rooms']=df_housing['total_bedrooms'] / df_housing['total_rooms']
df_housing['population_per_households']=df_housing['population'] / df_housing['households']

# %%
# Check the correlation again
df_housing.corr()['median_house_value'].sort_values(ascending=False)
# Out:
# median_house_value           1.000000
# median_income                0.688075
# rooms_per_households         0.151948
# total_rooms                  0.134153
# housing_median_age           0.105623
# households                   0.065843
# total_bedrooms               0.049686
# population_per_households   -0.023737
# population                  -0.024650
# longitude                   -0.045967
# latitude                    -0.144160
# bedrooms_per_rooms          -0.255880
# Name: median_house_value, dtype: float64

# %% [markdown]
# * > `Comment: Some progress for out new features (very good), strong correlation `

# %% [markdown]
# # `Split the DataSet`
# #### `I Split the DataSet uding ordinary method (Random method) not (stratified method)`

# %%
# split the whole DataSet to Features & Target
X = df_housing.drop(columns='median_house_value', axis=1)
y = df_housing['median_house_value']

# %%
# Random split the DataSet to two sets (train_set, Test_set)
# For validation --> I will use cross validation
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, shuffle=True, random_state=42)

# Check shapes for the sets
print("X_train shape -- ", X_train.shape)
print("X_test shape -- ", X_test.shape)
print("y_train shape -- ", y_train.shape)
print("y_test shape -- ", y_test.shape)
# Out:
# X_train shape --  (17544, 12)
# X_test shape --  (3096, 12)
# y_train shape --  (17544,)
# y_test shape --  (3096,)

# %% [markdown]
# * `Notes in sklearn, Read Carefully:`
#     * `.fit --> means that the instance you created istrying to learn or train`
#     * `.transform --> means that the instance you created has learned and now tinme to apply what it learned by transfoerming`
#     * `.fit_transform --> means the two above steps in one step, and don't use this method excepting with trainnig data`
#     * `We fit to train the data, and after it learns we transform (train, valid, test)`
#     * `In order --> (.fit) then (.transform) to training data or (.fit_transform) in one step`
#     * `In other meaning --> only (.transform) to other data after learning to training data`

# %% [markdown]
# ## `Dealing with nulls`

# %%
# Seperate the columns according to types (numerical and categorical)
num_cols = [col for col in X_train.columns if X_train[col].dtype in ['int64', 'int32', 'float64', 'float32']]
categ_cols = [col for col in X_train.columns if X_train[col].dtype not in ['int64', 'int32', 'float64', 'float32']]
categ_cols
# Out:
# ['ocean_proximity']

# %%
# What about imputing nulls using (median) --> using SimpleImputer
imputer =SimpleImputer(strategy='median')
X_train_filled = imputer.fit_transform(X_train[num_cols])
X_test_filled = imputer.transform(X_test[num_cols])

# %% [markdown]
# # `Standardize the Features`

# %%
# Using StandardScaler for each feature to be (mean=0, std=1)
# This technique helps for better training and to converge faster and put all features in the same scale
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_filled)  # train
X_test_scaled = scaler.transform(X_test_filled)   # test

# %% [markdown]
# ## `Pipeline for numerical features -- I will use it in this project`
# ### `Building a pipeline is much easier and better while inference at new dataset`

# %%
# building pipeline for numerical variables
num_pipeline = Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
                ('scaler', StandardScaler())])
# Deal with (num_pipeline) as an instance -- fit and transform to train dataset and transform only to other dataset
X_train_num = num_pipeline.fit_transform(X_train[num_cols])    # train
X_test_num = num_pipeline.transform(X_test[num_cols])   # test

# %% [markdown]
# ## `Categorical Features`
# ##### `Categorical features should be encoded before being passed to the model, there are more than one type of encoding`
#   * `Label encoding: mapping categories to numbers start from 0 to the length of categories and map these values in one column`
#   * `Ordinal encoding: mapping ordinal categories start from 0 to the length of categories but ordered 0<1<2< ...`
#   * `OHE = One Hot Encoding: mapped to multiple columns, column for each category, each column contains ones when this category      in mentioned`

# %%
# Let's use here for (ocean_proximity) --> use Label Encoder (Try to use OHE)
lbl_encoder = LabelEncoder()
lbl_encoder.fit(np.squeeze(X_train[categ_cols].values))

X_train_encoded = lbl_encoder.transform(np.squeeze(X_train[categ_cols].values))   # learn and transform for train
X_test_encoded = lbl_encoder.transform(np.squeeze(X_test[categ_cols].values))     # transform only for test

# Let's use OneHotEncoding
ohe = OneHotEncoder()
ohe.fit(X_train[categ_cols].values)

X_train_encoded = lbl_encoder.transform(np.squeeze(X_train[categ_cols].values))   # learn and transform for train
X_test_encoded = lbl_encoder.transform(np.squeeze(X_test[categ_cols].values))     # transform only for test

# %% [markdown]
# ## `Pipeline for categorical features -- I will use it in this project`

# %% [markdown]
# * `Use OHE -> it is preferable to use OHE when encoding for features, but if you are encoding for the target, you MUST encode using labelEncoder, except in Deep Learning we can use OHE for target, but for now, you can use LabelEncoder, OrdinalEncoder or OneHotEncoder for Features and only LabelEncoder for target --- Take care of this note`

# %%
# define pipeline for categorical columns --> use OneHotEncoder = OHE
categ_pipeline = Pipeline(steps=[('imputer', SimpleImputer(strategy='constant', fill_value='Missing')),
                               ('ohe', OneHotEncoder(sparse=False))])

# Deal with categ_pipeline is an instance -- fit and transform to train dataset and transform only to other dataset
X_train_categ = categ_pipeline.fit_transform(X_train[categ_cols])
X_test_categ = categ_pipeline.transform(X_test[categ_cols])

# %% [markdown]
# ## `Get all together`

# %% [markdown]
# * `Now we have outputs from numerical pipeline and categorical pipeline`
# * `We have to solutions:`
#     * `Concatenate the features (Numerical after processing) and (Encoded categorical features)`
#     * `You can use (FeatureUnion or Coulumn transformer) provided in sklearn`

# %%
# We can get much easier like the following
num_pipeline = Pipeline(steps=[('selector', DataFrameSelector(num_cols)),
                               ('imputer', SimpleImputer(strategy='median')),
                               ('scaler', StandardScaler())])

categ_pipeline = Pipeline(steps=[('selector', DataFrameSelector(categ_cols)),
                                 ('imputer', SimpleImputer(strategy='constant', fill_value='Missing')),
                                 ('ohe', OneHotEncoder(sparse=False))])

total_pipeline = FeatureUnion(transformer_list=[('num', num_pipeline), ('categ', categ_pipeline)])


# Deal with categ_pipeline is an instance -- fit and transform to train dataset and transform only to other dataset
X_train_final = total_pipeline.fit_transform(X_train)
X_test_final = total_pipeline.transform(X_test)   # Every thing is processed

# %% [markdown]
# ## `Building ML Models`
# ##### `Evaluation Metric: RMSE`

# %% [markdown]
# ### `1. LinearRegression`

# %%
# LinearRegression -- Regression using Ordinary Least Squares (OLS) method
lin_reg = LinearRegression()
lin_reg.fit(X_train_final, y_train)
# Out:
# LinearRegression()

# %%
mse_scores_lin = cross_val_score(estimator=lin_reg, X=X_train_final, y=y_train,
                                 cv=5, scoring='neg_mean_squared_error')
mse_scores_lin = mse_scores_lin * -1
rmse_score_lin = np.sqrt(mse_scores_lin)
rmse_score_lin.mean()
# Out:
# 67880.14257788868

# %%
# check scores of this model (RMSE) using (cross_val_score)
y_pred_lin = cross_val_predict(estimator=lin_reg, X=X_train_final, y=y_train,
                                 cv=5, method='predict')

# %% [markdown]
# ### `2. SGDRegressor`

# %%
# Define the model -- Initialize some random hyperparameters --> We will tune them later
sgd_reg = SGDRegressor(penalty='l2', shuffle=True, alpha=0.0001, max_iter=10000, random_state=42, eta0=0.0001)
sgd_reg.fit(X_train_final, y_train)
# Out:
# SGDRegressor(eta0=0.0001, max_iter=10000, random_state=42)

# %%
# Check scores of this model (RMSE) using (cross_val_score)
mse_scores_sgd = cross_val_score(estimator=sgd_reg, X=X_train_final, y=y_train,
                                 cv=5, scoring='neg_mean_squared_error')
mse_scores_sgd = mse_scores_sgd * -1
rmse_score_sgd = np.sqrt(mse_scores_sgd)
rmse_score_sgd.mean()
# Out:
# 67951.9675221288

# %% [markdown]
# ### `3. Ridge`
# ##### `Regression using Ordinary Least Squares, but Regularized version of LinearRegression using (L2 Norm)`

# %%
# Define Ridge model (Regularized version of LinearRegression)
ridge_reg = Ridge(alpha=0.9, solver='cholesky')
ridge_reg.fit(X_train_final, y_train)  # train the model
# Out:
# Ridge(alpha=0.9, solver='cholesky')

# %%
# Check scores of this model (RMSE) using (cross_val_score)
mse_scores_ridge = cross_val_score(estimator=ridge_reg, X=X_train_final, y=y_train,
                                 cv=5, scoring='neg_mean_squared_error')
mse_scores_ridge = mse_scores_ridge * -1
rmse_score_ridge = np.sqrt(mse_scores_ridge)
rmse_score_ridge.mean()
# Out:
# 67880.21922984188

# %% [markdown]
# ### `4. Lasso`
# ##### `Regression using Ordinary Least Squares, but Regularized version of LinearRegression using (L1 Norm)`

# %%
# Define Lasso model (Regularized version of LinearRegression)
lasso_reg = Lasso(alpha=1, max_iter=100000)
lasso_reg.fit(X_train_final, y_train)  # train the model
# Out:
# Lasso(alpha=1, max_iter=100000)

# %%
# Check the weights using Lasso, and ridge --- Lasso is a Features Selection model? why?
mse_scores_lasso = cross_val_score(estimator=lasso_reg, X=X_train_final, y=y_train,
                                 cv=5, scoring='neg_mean_squared_error')
mse_scores_lasso = mse_scores_lasso * -1
rmse_score_lasso = np.sqrt(mse_scores_lasso)
rmse_score_lasso.mean()
# Out:
# 67879.97230187681

# %% [markdown]
# ### `5. ElasticNet`
# ##### `Regression using Ordinary Least Squares, but Regularized version of LinearRegression using (L1 Norm & L2 Norm)`

# %%
# Define ElasticNet model (Regularized version of LinearRegression)
elastic_reg = ElasticNet(alpha=1, l1_ratio=0.9)
elastic_reg.fit(X_train_final, y_train)  # train the model
# Out:
# ElasticNet(alpha=1, l1_ratio=0.9)

# %%
# Check the weights using Lasso, and ridge --- Lasso is a Features Selection model? why?
mse_scores_elastic = cross_val_score(estimator=elastic_reg, X=X_train_final, y=y_train,
                                 cv=5, scoring='neg_mean_squared_error')
mse_scores_elastic = mse_scores_elastic * -1
rmse_score_elastic = np.sqrt(mse_scores_elastic)
rmse_score_elastic.mean()
# Out:
# 69603.81986345883

# %% [markdown]
# ### `6. PolynomialRegression`

# %%
# We can try to use PolynomialRegression
poly_feat = PolynomialFeatures(degree=3, include_bias=False)
X_poly = poly_feat.fit_transform(X_train_final)

# %%
# Pass the above new poly Features to the model -- bias is included in model itself -- don't add it twice
lin_reg_poly = LinearRegression()
lin_reg_poly.fit(X_poly, y_train)
# Out:
# LinearRegression()

# %%
# Check scores of this model (RMSE) using (cross_val_score)
# Check the weights using Lasso, and ridge --- Lasso is a Features Selection model? why?
mse_scores_poly = cross_val_score(estimator=lin_reg_poly, X=X_train_final, y=y_train,
                                 cv=5, scoring='neg_mean_squared_error')
mse_scores_poly = mse_scores_poly * -1
rmse_score_poly = np.sqrt(mse_scores_poly)
rmse_score_poly.mean()
# Out:
# 67880.14257788868

# %% [markdown]
# ### `7. KNN`

# %%
# Using KNN, low n_neighbors -> Overfitting & high n_neighbors -> Underfitting
knn_reg = KNeighborsRegressor(n_neighbors=6, weights='uniform', p=2, metric='minkowski')
knn_reg.fit(X_train_final, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=6)

# %%
# Check scores of this model (RMSE) using (cross_val_score)
mse_scores_knn = cross_val_score(estimator=knn_reg, X=X_train_final, y=y_train,
                                 cv=5, scoring='neg_mean_squared_error')
mse_scores_knn = mse_scores_knn * -1      #we want it positive
rmse_score_knn = np.sqrt(mse_scores_knn)
print(f"RMSE score using KNN --- {np.round(rmse_score_knn, 4)}")
print(f"Mean of RMSE score using KNN --- {rmse_score_knn.mean(): .4f}")

print('****'*30)

# Get prediction using (cross_val_predict)
y_pred_knn = cross_val_predict(estimator=knn_reg, X=X_train_final, y=y_train, method='predict', cv=5)

# You can check the (RMSE) using what model predicts and compare it with the mean of above result -- almost the same
# Take care of this point --> don't use .predict when you are using (Cross_Validation)
rmse_pred_knn = np.sqrt(mean_squared_error(y_train, y_pred_knn))
print(f'RMSE after prediction using KNN --- {rmse_pred_knn: .4f}')    # almost the same result
# Out:
# RMSE score using KNN --- [61716.6169 62099.3189 60883.1409 59936.0617 61775.7635]
# Mean of RMSE score using KNN ---  61282.1804
# ************************************************************************************************************************
# RMSE after prediction using KNN ---  61287.1640

# %% [markdown]
# ### `8. Random Forest`

# %%
# Using RF ---> a lot of hyperparameters but the dominant (n_estimator, max_depth)
forest_reg = RandomForestRegressor(n_estimators=150, max_depth=6,max_samples=.8, random_state=42)
forest_reg.fit(X_train_final, y_train)
# Out:
# RandomForestRegressor(max_depth=6, max_samples=0.8, n_estimators=150,
#                       random_state=42)

# %%
# Check scores of this model (RMSE) using (cross_val_score)
mse_scores_forest = cross_val_score(estimator=forest_reg, X=X_train_final, y=y_train,
                                 cv=5, scoring='neg_mean_squared_error')
mse_scores_forest = mse_scores_forest * -1      #we want it positive
rmse_score_forest = np.sqrt(mse_scores_forest)
print(f"RMSE score using Random Forest --- {np.round(rmse_score_forest, 4)}")
print(f"Mean of RMSE score using Random Forest --- {rmse_score_forest.mean(): .4f}")

print('****'*30)

# Get prediction using (cross_val_predict)
y_pred_forest = cross_val_predict(estimator=forest_reg, X=X_train_final, y=y_train, method='predict', cv=5)

# You can check the (RMSE) using what model predicts and compare it with the mean of above result -- almost the same
# Take care of this point --> don't use .predict when you are using (Cross_Validation)
rmse_pred_forest = np.sqrt(mean_squared_error(y_train, y_pred_forest))
print(f'RMSE after prediction using Random Forest --- {rmse_pred_forest: .4f}')    # almost the same result
# Out:
# RMSE score using Random Forest --- [58925.9674 61130.1728 60472.2879 58330.2278 60989.7339]
# Mean of RMSE score using Random Forest ---  59969.6780
# ************************************************************************************************************************
# RMSE after prediction using Random Forest ---  59980.3194

# %% [markdown]
# ### `RF Tuning`

# %%
params_best_forest = {'n_estimators': np.arange(100, 500, 50), 
                      'max_depth': np.arange(4, 20, 2), 
                      'max_samples': [0.7, 0.8, 0.9, 1]}
search_random_forest = RandomizedSearchCV(estimator=forest_reg, param_distributions=params_best_forest, 
                   n_iter=20, random_state=422, scoring='neg_mean_squared_error', cv=5, verbose=6)
search_random_forest.fit(X_train_final, y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END max_depth=18, max_samples=0.7, n_estimators=150;, score=-2391187635.752 total time=   8.4s
# [CV 2/5] END max_depth=18, max_samples=0.7, n_estimators=150;, score=-2781205995.392 total time=   8.4s
# [CV 3/5] END max_depth=18, max_samples=0.7, n_estimators=150;, score=-2645155556.888 total time=   8.3s
# [CV 4/5] END max_depth=18, max_samples=0.7, n_estimators=150;, score=-2418477575.713 total time=   8.4s
# [CV 5/5] END max_depth=18, max_samples=0.7, n_estimators=150;, score=-2556063413.546 total time=   8.5s
# [CV 1/5] END max_depth=12, max_samples=0.9, n_estimators=250;, score=-2492709737.035 total time=  13.5s
# [CV 2/5] END max_depth=12, max_samples=0.9, n_estimators=250;, score=-2884779798.841 total time=  13.0s
# [CV 3/5] END max_depth=12, max_samples=0.9, n_estimators=250;, score=-2755109200.857 total time=  13.0s
# [CV 4/5] END max_depth=12, max_samples=0.9, n_estimators=250;, score=-2509031588.719 total time=  13.4s
# [CV 5/5] END max_depth=12, max_samples=0.9, n_estimators=250;, score=-2675278522.861 total time=  13.3s
# [CV 1/5] END max_depth=4, max_samples=0.9, n_estimators=450;, score=-4363008374.205 total time=   9.3s
# [CV 2/5] END max_depth=4, max_samples=0.9, n_estimators=450;, score=-4613916736.835 total time=   9.2s
# [CV 3/5] END max_depth=4, max_samples=0.9, n_estimators=450;, score=-4556763022.533 total time=   9.4s
# [CV 4/5] END max_depth=4, max_samples=0.9, n_estimators=450;, score=-4364315612.634 total time=   9.3s
# [CV 5/5] END max_depth=4, max_samples=0.9, n_estimators=450;, score=-4678403786.823 total time=   9.3s
# [CV 1/5] END max_depth=16, max_samples=1, n_estimators=400;, score=-13235030133.940 total time=   0.2s
# [CV 2/5] END max_depth=16, max_samples=1, n_estimators=400;, score=-13543766619.466 total time=   0.2s
# [CV 3/5] END max_depth=16, max_samples=1, n_estimators=400;, score=-13459554148.446 total time=   0.2s
# [CV 4/5] END max_depth=16, max_samples=1, n_estimators=400;, score=-13130555847.484 total time=   0.2s
# [CV 5/5] END max_depth=16, max_samples=1, n_estimators=400;, score=-13441716793.631 total time=   0.2s
# [CV 1/5] END max_depth=4, max_samples=0.9, n_estimators=150;, score=-4369104287.157 total time=   3.0s
# [CV 2/5] END max_depth=4, max_samples=0.9, n_estimators=150;, score=-4627515160.799 total time=   3.0s
# [CV 3/5] END max_depth=4, max_samples=0.9, n_estimators=150;, score=-4554531856.083 total time=   3.1s
# [CV 4/5] END max_depth=4, max_samples=0.9, n_estimators=150;, score=-4363769878.594 total time=   3.0s
# [CV 5/5] END max_depth=4, max_samples=0.9, n_estimators=150;, score=-4679557133.015 total time=   3.0s
# [CV 1/5] END max_depth=18, max_samples=0.7, n_estimators=100;, score=-2386579381.341 total time=   5.5s
# [CV 2/5] END max_depth=18, max_samples=0.7, n_estimators=100;, score=-2781987065.939 total time=   5.6s
# [CV 3/5] END max_depth=18, max_samples=0.7, n_estimators=100;, score=-2651734605.069 total time=   5.5s
# [CV 4/5] END max_depth=18, max_samples=0.7, n_estimators=100;, score=-2432959698.551 total time=   5.5s
# [CV 5/5] END max_depth=18, max_samples=0.7, n_estimators=100;, score=-2576642653.776 total time=   5.5s
# [CV 1/5] END max_depth=4, max_samples=0.7, n_estimators=450;, score=-4333927645.128 total time=   7.9s
# [CV 2/5] END max_depth=4, max_samples=0.7, n_estimators=450;, score=-4594963382.731 total time=   7.9s
# [CV 3/5] END max_depth=4, max_samples=0.7, n_estimators=450;, score=-4515359111.917 total time=   7.9s
# [CV 4/5] END max_depth=4, max_samples=0.7, n_estimators=450;, score=-4340966380.925 total time=   7.9s
# [CV 5/5] END max_depth=4, max_samples=0.7, n_estimators=450;, score=-4644599357.248 total time=   7.9s
# [CV 1/5] END max_depth=14, max_samples=1, n_estimators=150;, score=-13234179920.512 total time=   0.0s
# [CV 2/5] END max_depth=14, max_samples=1, n_estimators=150;, score=-13544027083.430 total time=   0.0s
# [CV 3/5] END max_depth=14, max_samples=1, n_estimators=150;, score=-13473425905.865 total time=   0.0s
# [CV 4/5] END max_depth=14, max_samples=1, n_estimators=150;, score=-13133337480.604 total time=   0.0s
# [CV 5/5] END max_depth=14, max_samples=1, n_estimators=150;, score=-13489042553.576 total time=   0.0s
# [CV 1/5] END max_depth=14, max_samples=0.9, n_estimators=350;, score=-2411057478.561 total time=  20.7s
# [CV 2/5] END max_depth=14, max_samples=0.9, n_estimators=350;, score=-2799756565.145 total time=  20.6s
# [CV 3/5] END max_depth=14, max_samples=0.9, n_estimators=350;, score=-2669985448.147 total time=  20.6s
# [CV 4/5] END max_depth=14, max_samples=0.9, n_estimators=350;, score=-2430334811.773 total time=  20.8s
# [CV 5/5] END max_depth=14, max_samples=0.9, n_estimators=350;, score=-2594275369.811 total time=  20.7s
# [CV 1/5] END max_depth=4, max_samples=0.7, n_estimators=100;, score=-4343527206.188 total time=   1.7s
# [CV 2/5] END max_depth=4, max_samples=0.7, n_estimators=100;, score=-4595752290.717 total time=   1.7s
# [CV 3/5] END max_depth=4, max_samples=0.7, n_estimators=100;, score=-4511938260.598 total time=   1.7s
# [CV 4/5] END max_depth=4, max_samples=0.7, n_estimators=100;, score=-4354979168.539 total time=   1.7s
# [CV 5/5] END max_depth=4, max_samples=0.7, n_estimators=100;, score=-4659343484.143 total time=   1.7s
# [CV 1/5] END max_depth=14, max_samples=0.7, n_estimators=450;, score=-2432227950.467 total time=  23.5s
# [CV 2/5] END max_depth=14, max_samples=0.7, n_estimators=450;, score=-2797770234.010 total time=  24.3s
# [CV 3/5] END max_depth=14, max_samples=0.7, n_estimators=450;, score=-2683139741.340 total time=  22.0s
# [CV 4/5] END max_depth=14, max_samples=0.7, n_estimators=450;, score=-2463316882.146 total time=  22.9s
# [CV 5/5] END max_depth=14, max_samples=0.7, n_estimators=450;, score=-2594037667.072 total time=  23.6s
# [CV 1/5] END max_depth=18, max_samples=0.8, n_estimators=200;, score=-2386550988.838 total time=  12.7s
# [CV 2/5] END max_depth=18, max_samples=0.8, n_estimators=200;, score=-2736224491.151 total time=  13.3s
# [CV 3/5] END max_depth=18, max_samples=0.8, n_estimators=200;, score=-2638663968.563 total time=  12.6s
# [CV 4/5] END max_depth=18, max_samples=0.8, n_estimators=200;, score=-2403272976.739 total time=  12.5s
# [CV 5/5] END max_depth=18, max_samples=0.8, n_estimators=200;, score=-2534131573.546 total time=  12.5s
# [CV 1/5] END max_depth=18, max_samples=0.9, n_estimators=400;, score=-2357112767.424 total time=  27.5s
# [CV 2/5] END max_depth=18, max_samples=0.9, n_estimators=400;, score=-2733354599.049 total time=  28.0s
# [CV 3/5] END max_depth=18, max_samples=0.9, n_estimators=400;, score=-2626227076.347 total time=  27.2s
# [CV 4/5] END max_depth=18, max_samples=0.9, n_estimators=400;, score=-2384853708.286 total time=  27.2s
# [CV 5/5] END max_depth=18, max_samples=0.9, n_estimators=400;, score=-2525259384.231 total time=  27.7s
# [CV 1/5] END max_depth=6, max_samples=0.8, n_estimators=400;, score=-3464306962.174 total time=  11.6s
# [CV 2/5] END max_depth=6, max_samples=0.8, n_estimators=400;, score=-3739278910.384 total time=  11.2s
# [CV 3/5] END max_depth=6, max_samples=0.8, n_estimators=400;, score=-3665393056.026 total time=  11.2s
# [CV 4/5] END max_depth=6, max_samples=0.8, n_estimators=400;, score=-3406960840.695 total time=  11.1s
# [CV 5/5] END max_depth=6, max_samples=0.8, n_estimators=400;, score=-3709478190.579 total time=  11.3s
# [CV 1/5] END max_depth=16, max_samples=0.7, n_estimators=100;, score=-2398153528.453 total time=   5.6s
# [CV 2/5] END max_depth=16, max_samples=0.7, n_estimators=100;, score=-2795170399.678 total time=   5.6s
# [CV 3/5] END max_depth=16, max_samples=0.7, n_estimators=100;, score=-2671697466.346 total time=   5.4s
# [CV 4/5] END max_depth=16, max_samples=0.7, n_estimators=100;, score=-2440605687.250 total time=   5.4s
# [CV 5/5] END max_depth=16, max_samples=0.7, n_estimators=100;, score=-2584133904.908 total time=   5.4s
# [CV 1/5] END max_depth=4, max_samples=1, n_estimators=150;, score=-13234179920.512 total time=   0.0s
# [CV 2/5] END max_depth=4, max_samples=1, n_estimators=150;, score=-13544027083.430 total time=   0.0s
# [CV 3/5] END max_depth=4, max_samples=1, n_estimators=150;, score=-13473425905.865 total time=   0.0s
# [CV 4/5] END max_depth=4, max_samples=1, n_estimators=150;, score=-13133337480.604 total time=   0.0s
# [CV 5/5] END max_depth=4, max_samples=1, n_estimators=150;, score=-13489042553.576 total time=   0.0s
# [CV 1/5] END max_depth=18, max_samples=0.7, n_estimators=350;, score=-2384896179.131 total time=  21.0s
# [CV 2/5] END max_depth=18, max_samples=0.7, n_estimators=350;, score=-2759362249.987 total time=  21.8s
# [CV 3/5] END max_depth=18, max_samples=0.7, n_estimators=350;, score=-2648709690.778 total time=  21.6s
# [CV 4/5] END max_depth=18, max_samples=0.7, n_estimators=350;, score=-2414566168.514 total time=  20.7s
# [CV 5/5] END max_depth=18, max_samples=0.7, n_estimators=350;, score=-2539287365.132 total time=  19.9s
# [CV 1/5] END max_depth=8, max_samples=0.8, n_estimators=300;, score=-2969350121.079 total time=  10.6s
# [CV 2/5] END max_depth=8, max_samples=0.8, n_estimators=300;, score=-3285813274.305 total time=  10.7s
# [CV 3/5] END max_depth=8, max_samples=0.8, n_estimators=300;, score=-3182203195.062 total time=  10.7s
# [CV 4/5] END max_depth=8, max_samples=0.8, n_estimators=300;, score=-2937062175.245 total time=  10.8s
# [CV 5/5] END max_depth=8, max_samples=0.8, n_estimators=300;, score=-3167555811.524 total time=  10.8s
# [CV 1/5] END max_depth=10, max_samples=0.9, n_estimators=200;, score=-2658938570.651 total time=   9.3s
# [CV 2/5] END max_depth=10, max_samples=0.9, n_estimators=200;, score=-3021868487.061 total time=   9.2s
# [CV 3/5] END max_depth=10, max_samples=0.9, n_estimators=200;, score=-2890791695.039 total time=   9.3s
# [CV 4/5] END max_depth=10, max_samples=0.9, n_estimators=200;, score=-2650967632.207 total time=   9.2s
# [CV 5/5] END max_depth=10, max_samples=0.9, n_estimators=200;, score=-2857451876.854 total time=   9.1s
# [CV 1/5] END max_depth=10, max_samples=0.9, n_estimators=250;, score=-2659975587.385 total time=  11.5s
# [CV 2/5] END max_depth=10, max_samples=0.9, n_estimators=250;, score=-3019444271.934 total time=  11.6s
# [CV 3/5] END max_depth=10, max_samples=0.9, n_estimators=250;, score=-2896584447.325 total time=  11.6s
# [CV 4/5] END max_depth=10, max_samples=0.9, n_estimators=250;, score=-2654284725.633 total time=  11.6s
# [CV 5/5] END max_depth=10, max_samples=0.9, n_estimators=250;, score=-2853153838.136 total time=  11.5s
# RandomizedSearchCV(cv=5,
#                    estimator=RandomForestRegressor(max_depth=6, max_samples=0.8,
#                                                    n_estimators=150,
#                                                    random_state=42),
#                    n_iter=20,
#                    param_distributions={'max_depth': array([ 4,  6,  8, 10, 12, 14, 16, 18]),
#                                         'max_samples': [0.7, 0.8, 0.9, 1],
#                                         'n_estimators': array([100, 150, 200, 250, 300, 350, 400, 450])},
#                    random_state=422, scoring='neg_mean_squared_error',
#                    verbose=6)

# %%
best_forest = search_random_forest.best_estimator_

# %%
# Check scores of this model (RMSE) using (cross_val_score)
mse_scores_tuned_forest = cross_val_score(estimator=best_forest, X=X_train_final, y=y_train,
                                 cv=5, scoring='neg_mean_squared_error')
mse_scores_tuned_forest = mse_scores_tuned_forest * -1      #we want it positive
rmse_score_tuned_forest = np.sqrt(mse_scores_tuned_forest)
print(f"RMSE score using tuned Random Forest --- {np.round(rmse_score_tuned_forest, 4)}")
print(f"Mean of RMSE score using tuned Random Forest --- {rmse_score_tuned_forest.mean(): .4f}")

print('****'*30)

# Get prediction using (cross_val_predict)
y_pred_tuned_forest = cross_val_predict(estimator=best_forest, X=X_train_final, y=y_train, method='predict', cv=5)

# You can check the (RMSE) using what model predicts and compare it with the mean of above result -- almost the same
# Take care of this point --> don't use .predict when you are using (Cross_Validation)
rmse_pred_tuned_forest = np.sqrt(mean_squared_error(y_train, y_pred_tuned_forest))
print(f'RMSE after prediction using tuned Random Forest --- {rmse_pred_tuned_forest: .4f}')    # almost the same result
# Out:
# RMSE score using tuned Random Forest --- [48550.1057 52281.4938 51246.7275 48834.964  50251.959 ]
# Mean of RMSE score using tuned Random Forest ---  50233.0500
# ************************************************************************************************************************
# RMSE after prediction using tuned Random Forest ---  50252.9752

# %% [markdown]
# ### `Feature Importance using RF`

# %%
# Getting the features importance (they are normalized in RF, sum=1)
feat_import_forest = {}
for name, score in zip(num_cols, best_forest.feature_importances_[:11]):
    feat_import_forest[name] = score

# %%
keys_forest = feat_import_forest.keys()
values_forest = feat_import_forest.values()

# %%
# To DF and plotting
df_feat_import_forest = pd.DataFrame({'Features': keys_forest, 'scores': values_forest})
df_feat_import_forest = df_feat_import_forest.sort_values(by='scores', ascending=False)
plt.figure(figsize=(12, 8))
plt.barh(y=df_feat_import_forest['Features'], width=df_feat_import_forest['scores'])
plt.title('Features Importance using RandomForest Model', fontsize=16, c='k')
plt.xlabel('Scores', fontsize=16, c='k')
plt.ylabel('Features', fontsize=16, c='k')
plt.xticks(c='k', fontsize=12)
plt.yticks(c='k', fontsize=12)
plt.grid('on')
plt.show()

# %% [markdown]
# ### `9. XGBoost`

# %%
# using the hero API -->
xgb_reg = xgboost.XGBRegressor(n_estimators=100, max_depth=6, learning_rate=0.1, subsample=0.8, )
xgb_reg.fit(X_train_final, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=6, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# Check scores of this model (RMSE) using (cross_val_score)
mse_scores_xgb = cross_val_score(estimator=xgb_reg, X=X_train_final, y=y_train,
                                 cv=5, scoring='neg_mean_squared_error')
mse_scores_xgb = mse_scores_xgb * -1      #we want it positive
rmse_score_xgb = np.sqrt(mse_scores_xgb)
print(f"RMSE score using tuned Random Forest --- {np.round(rmse_score_xgb, 4)}")
print(f"Mean of RMSE score using tuned Random Forest --- {rmse_score_xgb.mean(): .4f}")

print('****'*30)

# Get prediction using (cross_val_predict)
y_pred_xgb = cross_val_predict(estimator=xgb_reg, X=X_train_final, y=y_train, method='predict', cv=5)

# You can check the (RMSE) using what model predicts and compare it with the mean of above result -- almost the same
# Take care of this point --> don't use .predict when you are using (Cross_Validation)
rmse_pred_xgb = np.sqrt(mean_squared_error(y_train, y_pred_xgb))
print(f'RMSE after prediction using tuned Random Forest --- {rmse_pred_xgb: .4f}')    # almost the same result
# Out:
# RMSE score using tuned Random Forest --- [46257.3372 48079.2801 48091.8238 45795.9642 48237.5764]
# Mean of RMSE score using tuned Random Forest ---  47292.3963
# ************************************************************************************************************************
# RMSE after prediction using tuned Random Forest ---  47303.8912

# %% [markdown]
# ### `Tuning XGBoost`

# %%
# Let's trying tuning XGBoost using GridSearchCV -- needs a lot of tuning
params_best_xgb = {'n_estimators': np.arange(100, 200, 50), 'max_depth': np.arange(4, 15, 2), 
                   'learning_rate': [0.1, 0.2], 'subsample': [0.8, 0.9]}
grid_xgb = GridSearchCV(estimator=xgb_reg, param_grid=params_best_xgb, cv=5, scoring='neg_mean_squared_error', verbose=6)
grid_xgb.fit(X_train_final, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 1/5] END learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.8;, score=-2435370122.441 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.8;, score=-2563263783.762 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.8;, score=-2529909876.961 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.8;, score=-2380119584.916 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.8;, score=-2675330996.869 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.9;, score=-2411196652.784 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.9;, score=-2532509295.384 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.9;, score=-2484357209.174 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.9;, score=-2343922991.108 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.9;, score=-2668232095.768 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=4, n_estimators=150, subsample=0.8;, score=-2297688554.607 total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=4, n_estimators=150, subsample=0.8;, score=-2420388951.861 total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=4, n_estimators=150, subsample=0.8;, score=-2378241833.685 total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=4, n_estimators=150, subsample=0.8;, score=-2268066842.507 total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=4, n_estimators=150, subsample=0.8;, score=-2549352450.719 total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=4, n_estimators=150, subsample=0.9;, score=-2272716731.403 total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=4, n_estimators=150, subsample=0.9;, score=-2381554158.293 total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=4, n_estimators=150, subsample=0.9;, score=-2346171435.346 total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=4, n_estimators=150, subsample=0.9;, score=-2227601524.659 total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=4, n_estimators=150, subsample=0.9;, score=-2520722683.013 total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=6, n_estimators=100, subsample=0.8;, score=-2139741245.872 total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=6, n_estimators=100, subsample=0.8;, score=-2311617171.301 total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=6, n_estimators=100, subsample=0.8;, score=-2312823518.282 total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=6, n_estimators=100, subsample=0.8;, score=-2097270333.740 total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=6, n_estimators=100, subsample=0.8;, score=-2326863780.881 total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=6, n_estimators=100, subsample=0.9;, score=-2076904789.695 total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=6, n_estimators=100, subsample=0.9;, score=-2325031545.628 total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=6, n_estimators=100, subsample=0.9;, score=-2294273689.249 total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=6, n_estimators=100, subsample=0.9;, score=-2110246161.659 total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=6, n_estimators=100, subsample=0.9;, score=-2324674934.507 total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=6, n_estimators=150, subsample=0.8;, score=-2061436288.941 total time=   0.2s
# [CV 2/5] END learning_rate=0.1, max_depth=6, n_estimators=150, subsample=0.8;, score=-2220647636.479 total time=   0.2s
# [CV 3/5] END learning_rate=0.1, max_depth=6, n_estimators=150, subsample=0.8;, score=-2212915018.993 total time=   0.2s
# [CV 4/5] END learning_rate=0.1, max_depth=6, n_estimators=150, subsample=0.8;, score=-2032150274.469 total time=   0.2s
# [CV 5/5] END learning_rate=0.1, max_depth=6, n_estimators=150, subsample=0.8;, score=-2210601470.645 total time=   0.2s
# [CV 1/5] END learning_rate=0.1, max_depth=6, n_estimators=150, subsample=0.9;, score=-2006502778.165 total time=   0.2s
# [CV 2/5] END learning_rate=0.1, max_depth=6, n_estimators=150, subsample=0.9;, score=-2247690703.087 total time=   0.2s
# [CV 3/5] END learning_rate=0.1, max_depth=6, n_estimators=150, subsample=0.9;, score=-2201041015.350 total time=   0.2s
# [CV 4/5] END learning_rate=0.1, max_depth=6, n_estimators=150, subsample=0.9;, score=-2039092474.061 total time=   0.2s
# [CV 5/5] END learning_rate=0.1, max_depth=6, n_estimators=150, subsample=0.9;, score=-2233287243.648 total time=   0.2s
# [CV 1/5] END learning_rate=0.1, max_depth=8, n_estimators=100, subsample=0.8;, score=-2085590961.846 total time=   0.3s
# [CV 2/5] END learning_rate=0.1, max_depth=8, n_estimators=100, subsample=0.8;, score=-2291285704.907 total time=   0.3s
# [CV 3/5] END learning_rate=0.1, max_depth=8, n_estimators=100, subsample=0.8;, score=-2186180628.699 total time=   0.3s
# [CV 4/5] END learning_rate=0.1, max_depth=8, n_estimators=100, subsample=0.8;, score=-2062276849.167 total time=   0.3s
# [CV 5/5] END learning_rate=0.1, max_depth=8, n_estimators=100, subsample=0.8;, score=-2214023741.713 total time=   0.3s
# [CV 1/5] END learning_rate=0.1, max_depth=8, n_estimators=100, subsample=0.9;, score=-2055025152.217 total time=   0.3s
# [CV 2/5] END learning_rate=0.1, max_depth=8, n_estimators=100, subsample=0.9;, score=-2282288439.542 total time=   0.3s
# [CV 3/5] END learning_rate=0.1, max_depth=8, n_estimators=100, subsample=0.9;, score=-2219382802.182 total time=   0.3s
# [CV 4/5] END learning_rate=0.1, max_depth=8, n_estimators=100, subsample=0.9;, score=-2043366498.195 total time=   0.3s
# [CV 5/5] END learning_rate=0.1, max_depth=8, n_estimators=100, subsample=0.9;, score=-2215914359.476 total time=   0.3s
# [CV 1/5] END learning_rate=0.1, max_depth=8, n_estimators=150, subsample=0.8;, score=-2039120699.676 total time=   0.4s
# [CV 2/5] END learning_rate=0.1, max_depth=8, n_estimators=150, subsample=0.8;, score=-2236418005.358 total time=   0.4s
# [CV 3/5] END learning_rate=0.1, max_depth=8, n_estimators=150, subsample=0.8;, score=-2145947497.493 total time=   0.4s
# [CV 4/5] END learning_rate=0.1, max_depth=8, n_estimators=150, subsample=0.8;, score=-2020333802.381 total time=   0.4s
# [CV 5/5] END learning_rate=0.1, max_depth=8, n_estimators=150, subsample=0.8;, score=-2163790902.198 total time=   0.6s
# [CV 1/5] END learning_rate=0.1, max_depth=8, n_estimators=150, subsample=0.9;, score=-2023252687.722 total time=   0.5s
# [CV 2/5] END learning_rate=0.1, max_depth=8, n_estimators=150, subsample=0.9;, score=-2247454329.675 total time=   0.4s
# [CV 3/5] END learning_rate=0.1, max_depth=8, n_estimators=150, subsample=0.9;, score=-2183282311.924 total time=   0.4s
# [CV 4/5] END learning_rate=0.1, max_depth=8, n_estimators=150, subsample=0.9;, score=-2024622542.643 total time=   0.4s
# [CV 5/5] END learning_rate=0.1, max_depth=8, n_estimators=150, subsample=0.9;, score=-2167689467.993 total time=   0.4s
# [CV 1/5] END learning_rate=0.1, max_depth=10, n_estimators=100, subsample=0.8;, score=-2064769919.466 total time=   0.7s
# [CV 2/5] END learning_rate=0.1, max_depth=10, n_estimators=100, subsample=0.8;, score=-2365299194.370 total time=   0.8s
# [CV 3/5] END learning_rate=0.1, max_depth=10, n_estimators=100, subsample=0.8;, score=-2212027396.686 total time=   0.7s
# [CV 4/5] END learning_rate=0.1, max_depth=10, n_estimators=100, subsample=0.8;, score=-2098929535.417 total time=   0.8s
# [CV 5/5] END learning_rate=0.1, max_depth=10, n_estimators=100, subsample=0.8;, score=-2237270159.402 total time=   0.7s
# [CV 1/5] END learning_rate=0.1, max_depth=10, n_estimators=100, subsample=0.9;, score=-2071187613.417 total time=   0.7s
# [CV 2/5] END learning_rate=0.1, max_depth=10, n_estimators=100, subsample=0.9;, score=-2329221921.568 total time=   0.8s
# [CV 3/5] END learning_rate=0.1, max_depth=10, n_estimators=100, subsample=0.9;, score=-2290760724.511 total time=   0.7s
# [CV 4/5] END learning_rate=0.1, max_depth=10, n_estimators=100, subsample=0.9;, score=-2086540541.185 total time=   0.8s
# [CV 5/5] END learning_rate=0.1, max_depth=10, n_estimators=100, subsample=0.9;, score=-2256795941.057 total time=   0.8s
# [CV 1/5] END learning_rate=0.1, max_depth=10, n_estimators=150, subsample=0.8;, score=-2052609350.086 total time=   1.0s
# [CV 2/5] END learning_rate=0.1, max_depth=10, n_estimators=150, subsample=0.8;, score=-2341582926.477 total time=   1.1s
# [CV 3/5] END learning_rate=0.1, max_depth=10, n_estimators=150, subsample=0.8;, score=-2195299354.152 total time=   1.1s
# [CV 4/5] END learning_rate=0.1, max_depth=10, n_estimators=150, subsample=0.8;, score=-2096749323.478 total time=   1.2s
# [CV 5/5] END learning_rate=0.1, max_depth=10, n_estimators=150, subsample=0.8;, score=-2213380621.761 total time=   1.1s
# [CV 1/5] END learning_rate=0.1, max_depth=10, n_estimators=150, subsample=0.9;, score=-2058596217.734 total time=   1.1s
# [CV 2/5] END learning_rate=0.1, max_depth=10, n_estimators=150, subsample=0.9;, score=-2308164349.636 total time=   1.2s
# [CV 3/5] END learning_rate=0.1, max_depth=10, n_estimators=150, subsample=0.9;, score=-2270704635.649 total time=   1.1s
# [CV 4/5] END learning_rate=0.1, max_depth=10, n_estimators=150, subsample=0.9;, score=-2080921619.902 total time=   1.3s
# [CV 5/5] END learning_rate=0.1, max_depth=10, n_estimators=150, subsample=0.9;, score=-2244247475.418 total time=   1.2s
# [CV 1/5] END learning_rate=0.1, max_depth=12, n_estimators=100, subsample=0.8;, score=-2166457909.204 total time=   2.0s
# [CV 2/5] END learning_rate=0.1, max_depth=12, n_estimators=100, subsample=0.8;, score=-2406562502.756 total time=   2.3s
# [CV 3/5] END learning_rate=0.1, max_depth=12, n_estimators=100, subsample=0.8;, score=-2312615528.119 total time=   2.0s
# [CV 4/5] END learning_rate=0.1, max_depth=12, n_estimators=100, subsample=0.8;, score=-2168812358.700 total time=   2.0s
# [CV 5/5] END learning_rate=0.1, max_depth=12, n_estimators=100, subsample=0.8;, score=-2300194097.158 total time=   1.9s
# [CV 1/5] END learning_rate=0.1, max_depth=12, n_estimators=100, subsample=0.9;, score=-2175656327.864 total time=   2.2s
# [CV 2/5] END learning_rate=0.1, max_depth=12, n_estimators=100, subsample=0.9;, score=-2374335094.412 total time=   2.4s
# [CV 3/5] END learning_rate=0.1, max_depth=12, n_estimators=100, subsample=0.9;, score=-2355720114.256 total time=   2.6s
# [CV 4/5] END learning_rate=0.1, max_depth=12, n_estimators=100, subsample=0.9;, score=-2198902717.758 total time=   2.9s
# [CV 5/5] END learning_rate=0.1, max_depth=12, n_estimators=100, subsample=0.9;, score=-2320384864.582 total time=   2.4s
# [CV 1/5] END learning_rate=0.1, max_depth=12, n_estimators=150, subsample=0.8;, score=-2158621968.739 total time=   3.4s
# [CV 2/5] END learning_rate=0.1, max_depth=12, n_estimators=150, subsample=0.8;, score=-2394868517.997 total time=   3.2s
# [CV 3/5] END learning_rate=0.1, max_depth=12, n_estimators=150, subsample=0.8;, score=-2302213969.808 total time=   2.8s
# [CV 4/5] END learning_rate=0.1, max_depth=12, n_estimators=150, subsample=0.8;, score=-2164071420.741 total time=   2.9s
# [CV 5/5] END learning_rate=0.1, max_depth=12, n_estimators=150, subsample=0.8;, score=-2287668822.103 total time=   2.7s
# [CV 1/5] END learning_rate=0.1, max_depth=12, n_estimators=150, subsample=0.9;, score=-2165946911.372 total time=   2.7s
# [CV 2/5] END learning_rate=0.1, max_depth=12, n_estimators=150, subsample=0.9;, score=-2365886223.798 total time=   2.7s
# [CV 3/5] END learning_rate=0.1, max_depth=12, n_estimators=150, subsample=0.9;, score=-2345649551.706 total time=   2.7s
# [CV 4/5] END learning_rate=0.1, max_depth=12, n_estimators=150, subsample=0.9;, score=-2195443521.786 total time=   2.9s
# [CV 5/5] END learning_rate=0.1, max_depth=12, n_estimators=150, subsample=0.9;, score=-2313906511.540 total time=   2.8s
# [CV 1/5] END learning_rate=0.1, max_depth=14, n_estimators=100, subsample=0.8;, score=-2199455018.646 total time=   3.5s
# [CV 2/5] END learning_rate=0.1, max_depth=14, n_estimators=100, subsample=0.8;, score=-2490465227.720 total time=   3.3s
# [CV 3/5] END learning_rate=0.1, max_depth=14, n_estimators=100, subsample=0.8;, score=-2407969345.583 total time=   3.5s
# [CV 4/5] END learning_rate=0.1, max_depth=14, n_estimators=100, subsample=0.8;, score=-2230341407.335 total time=   3.6s
# [CV 5/5] END learning_rate=0.1, max_depth=14, n_estimators=100, subsample=0.8;, score=-2358296818.507 total time=   4.0s
# [CV 1/5] END learning_rate=0.1, max_depth=14, n_estimators=100, subsample=0.9;, score=-2275674735.601 total time=   3.8s
# [CV 2/5] END learning_rate=0.1, max_depth=14, n_estimators=100, subsample=0.9;, score=-2459125066.307 total time=   3.6s
# [CV 3/5] END learning_rate=0.1, max_depth=14, n_estimators=100, subsample=0.9;, score=-2503577746.229 total time=   3.9s
# [CV 4/5] END learning_rate=0.1, max_depth=14, n_estimators=100, subsample=0.9;, score=-2251398868.334 total time=   4.0s
# [CV 5/5] END learning_rate=0.1, max_depth=14, n_estimators=100, subsample=0.9;, score=-2423990546.542 total time=   4.1s
# [CV 1/5] END learning_rate=0.1, max_depth=14, n_estimators=150, subsample=0.8;, score=-2193095996.722 total time=   4.9s
# [CV 2/5] END learning_rate=0.1, max_depth=14, n_estimators=150, subsample=0.8;, score=-2484037253.323 total time=   4.6s
# [CV 3/5] END learning_rate=0.1, max_depth=14, n_estimators=150, subsample=0.8;, score=-2404520629.979 total time=   4.8s
# [CV 4/5] END learning_rate=0.1, max_depth=14, n_estimators=150, subsample=0.8;, score=-2228573663.580 total time=   5.1s
# [CV 5/5] END learning_rate=0.1, max_depth=14, n_estimators=150, subsample=0.8;, score=-2353303429.706 total time=   5.3s
# [CV 1/5] END learning_rate=0.1, max_depth=14, n_estimators=150, subsample=0.9;, score=-2271031233.620 total time=   5.0s
# [CV 2/5] END learning_rate=0.1, max_depth=14, n_estimators=150, subsample=0.9;, score=-2452810025.307 total time=   4.8s
# [CV 3/5] END learning_rate=0.1, max_depth=14, n_estimators=150, subsample=0.9;, score=-2500192087.410 total time=   5.2s
# [CV 4/5] END learning_rate=0.1, max_depth=14, n_estimators=150, subsample=0.9;, score=-2250436337.631 total time=   5.2s
# [CV 5/5] END learning_rate=0.1, max_depth=14, n_estimators=150, subsample=0.9;, score=-2420508273.930 total time=   5.2s
# [CV 1/5] END learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.8;, score=-2224815205.306 total time=   0.0s
# [CV 2/5] END learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.8;, score=-2315610933.650 total time=   0.0s
# [CV 3/5] END learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.8;, score=-2388315798.375 total time=   0.0s
# [CV 4/5] END learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.8;, score=-2191540668.998 total time=   0.0s
# [CV 5/5] END learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.8;, score=-2470655890.729 total time=   0.0s
# [CV 1/5] END learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.9;, score=-2234523799.842 total time=   0.0s
# [CV 2/5] END learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.9;, score=-2319606108.414 total time=   0.0s
# [CV 3/5] END learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.9;, score=-2339722197.015 total time=   0.0s
# [CV 4/5] END learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.9;, score=-2183644957.510 total time=   0.0s
# [CV 5/5] END learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.9;, score=-2488998302.998 total time=   0.0s
# [CV 1/5] END learning_rate=0.2, max_depth=4, n_estimators=150, subsample=0.8;, score=-2162078074.675 total time=   0.0s
# [CV 2/5] END learning_rate=0.2, max_depth=4, n_estimators=150, subsample=0.8;, score=-2232117473.895 total time=   0.1s
# [CV 3/5] END learning_rate=0.2, max_depth=4, n_estimators=150, subsample=0.8;, score=-2337374790.111 total time=   0.1s
# [CV 4/5] END learning_rate=0.2, max_depth=4, n_estimators=150, subsample=0.8;, score=-2090616378.317 total time=   0.0s
# [CV 5/5] END learning_rate=0.2, max_depth=4, n_estimators=150, subsample=0.8;, score=-2383948253.937 total time=   0.1s
# [CV 1/5] END learning_rate=0.2, max_depth=4, n_estimators=150, subsample=0.9;, score=-2180377475.770 total time=   0.1s
# [CV 2/5] END learning_rate=0.2, max_depth=4, n_estimators=150, subsample=0.9;, score=-2228245479.517 total time=   0.1s
# [CV 3/5] END learning_rate=0.2, max_depth=4, n_estimators=150, subsample=0.9;, score=-2279174186.889 total time=   0.1s
# [CV 4/5] END learning_rate=0.2, max_depth=4, n_estimators=150, subsample=0.9;, score=-2138338918.018 total time=   0.1s
# [CV 5/5] END learning_rate=0.2, max_depth=4, n_estimators=150, subsample=0.9;, score=-2389401996.940 total time=   0.1s
# [CV 1/5] END learning_rate=0.2, max_depth=6, n_estimators=100, subsample=0.8;, score=-2100575706.587 total time=   0.1s
# [CV 2/5] END learning_rate=0.2, max_depth=6, n_estimators=100, subsample=0.8;, score=-2312435917.836 total time=   0.1s
# [CV 3/5] END learning_rate=0.2, max_depth=6, n_estimators=100, subsample=0.8;, score=-2267412606.582 total time=   0.1s
# [CV 4/5] END learning_rate=0.2, max_depth=6, n_estimators=100, subsample=0.8;, score=-2140587537.433 total time=   0.1s
# [CV 5/5] END learning_rate=0.2, max_depth=6, n_estimators=100, subsample=0.8;, score=-2303807454.207 total time=   0.1s
# [CV 1/5] END learning_rate=0.2, max_depth=6, n_estimators=100, subsample=0.9;, score=-2086629603.750 total time=   0.1s
# [CV 2/5] END learning_rate=0.2, max_depth=6, n_estimators=100, subsample=0.9;, score=-2256881096.774 total time=   0.1s
# [CV 3/5] END learning_rate=0.2, max_depth=6, n_estimators=100, subsample=0.9;, score=-2194716016.344 total time=   0.1s
# [CV 4/5] END learning_rate=0.2, max_depth=6, n_estimators=100, subsample=0.9;, score=-2053332301.595 total time=   0.1s
# [CV 5/5] END learning_rate=0.2, max_depth=6, n_estimators=100, subsample=0.9;, score=-2297204748.323 total time=   0.1s
# [CV 1/5] END learning_rate=0.2, max_depth=6, n_estimators=150, subsample=0.8;, score=-2097152993.086 total time=   0.2s
# [CV 2/5] END learning_rate=0.2, max_depth=6, n_estimators=150, subsample=0.8;, score=-2299188200.501 total time=   0.2s
# [CV 3/5] END learning_rate=0.2, max_depth=6, n_estimators=150, subsample=0.8;, score=-2240558481.370 total time=   0.1s
# [CV 4/5] END learning_rate=0.2, max_depth=6, n_estimators=150, subsample=0.8;, score=-2131531892.439 total time=   0.2s
# [CV 5/5] END learning_rate=0.2, max_depth=6, n_estimators=150, subsample=0.8;, score=-2255544579.177 total time=   0.2s
# [CV 1/5] END learning_rate=0.2, max_depth=6, n_estimators=150, subsample=0.9;, score=-2051657832.941 total time=   0.2s
# [CV 2/5] END learning_rate=0.2, max_depth=6, n_estimators=150, subsample=0.9;, score=-2225781306.030 total time=   0.2s
# [CV 3/5] END learning_rate=0.2, max_depth=6, n_estimators=150, subsample=0.9;, score=-2154373691.521 total time=   0.2s
# [CV 4/5] END learning_rate=0.2, max_depth=6, n_estimators=150, subsample=0.9;, score=-2034675477.951 total time=   0.2s
# [CV 5/5] END learning_rate=0.2, max_depth=6, n_estimators=150, subsample=0.9;, score=-2229277068.562 total time=   0.2s
# [CV 1/5] END learning_rate=0.2, max_depth=8, n_estimators=100, subsample=0.8;, score=-2106911310.851 total time=   0.3s
# [CV 2/5] END learning_rate=0.2, max_depth=8, n_estimators=100, subsample=0.8;, score=-2404689682.703 total time=   0.3s
# [CV 3/5] END learning_rate=0.2, max_depth=8, n_estimators=100, subsample=0.8;, score=-2268369372.828 total time=   0.3s
# [CV 4/5] END learning_rate=0.2, max_depth=8, n_estimators=100, subsample=0.8;, score=-2189208377.470 total time=   0.3s
# [CV 5/5] END learning_rate=0.2, max_depth=8, n_estimators=100, subsample=0.8;, score=-2222174251.324 total time=   0.3s
# [CV 1/5] END learning_rate=0.2, max_depth=8, n_estimators=100, subsample=0.9;, score=-2131960822.940 total time=   0.3s
# [CV 2/5] END learning_rate=0.2, max_depth=8, n_estimators=100, subsample=0.9;, score=-2321013974.713 total time=   0.3s
# [CV 3/5] END learning_rate=0.2, max_depth=8, n_estimators=100, subsample=0.9;, score=-2312378160.559 total time=   0.3s
# [CV 4/5] END learning_rate=0.2, max_depth=8, n_estimators=100, subsample=0.9;, score=-2138122622.465 total time=   0.3s
# [CV 5/5] END learning_rate=0.2, max_depth=8, n_estimators=100, subsample=0.9;, score=-2212200658.785 total time=   0.3s
# [CV 1/5] END learning_rate=0.2, max_depth=8, n_estimators=150, subsample=0.8;, score=-2092352408.829 total time=   0.4s
# [CV 2/5] END learning_rate=0.2, max_depth=8, n_estimators=150, subsample=0.8;, score=-2403345562.818 total time=   0.4s
# [CV 3/5] END learning_rate=0.2, max_depth=8, n_estimators=150, subsample=0.8;, score=-2258033447.111 total time=   0.4s
# [CV 4/5] END learning_rate=0.2, max_depth=8, n_estimators=150, subsample=0.8;, score=-2187608209.589 total time=   0.4s
# [CV 5/5] END learning_rate=0.2, max_depth=8, n_estimators=150, subsample=0.8;, score=-2233197116.611 total time=   0.4s
# [CV 1/5] END learning_rate=0.2, max_depth=8, n_estimators=150, subsample=0.9;, score=-2122928417.106 total time=   0.4s
# [CV 2/5] END learning_rate=0.2, max_depth=8, n_estimators=150, subsample=0.9;, score=-2318877596.245 total time=   0.4s
# [CV 3/5] END learning_rate=0.2, max_depth=8, n_estimators=150, subsample=0.9;, score=-2305557789.434 total time=   0.4s
# [CV 4/5] END learning_rate=0.2, max_depth=8, n_estimators=150, subsample=0.9;, score=-2144923884.122 total time=   0.4s
# [CV 5/5] END learning_rate=0.2, max_depth=8, n_estimators=150, subsample=0.9;, score=-2193033431.923 total time=   0.4s
# [CV 1/5] END learning_rate=0.2, max_depth=10, n_estimators=100, subsample=0.8;, score=-2157790147.098 total time=   0.6s
# [CV 2/5] END learning_rate=0.2, max_depth=10, n_estimators=100, subsample=0.8;, score=-2415000184.126 total time=   0.7s
# [CV 3/5] END learning_rate=0.2, max_depth=10, n_estimators=100, subsample=0.8;, score=-2347493780.264 total time=   0.7s
# [CV 4/5] END learning_rate=0.2, max_depth=10, n_estimators=100, subsample=0.8;, score=-2155222015.793 total time=   0.7s
# [CV 5/5] END learning_rate=0.2, max_depth=10, n_estimators=100, subsample=0.8;, score=-2283804367.782 total time=   0.7s
# [CV 1/5] END learning_rate=0.2, max_depth=10, n_estimators=100, subsample=0.9;, score=-2199352547.985 total time=   0.7s
# [CV 2/5] END learning_rate=0.2, max_depth=10, n_estimators=100, subsample=0.9;, score=-2415750794.432 total time=   0.8s
# [CV 3/5] END learning_rate=0.2, max_depth=10, n_estimators=100, subsample=0.9;, score=-2400695993.161 total time=   0.7s
# [CV 4/5] END learning_rate=0.2, max_depth=10, n_estimators=100, subsample=0.9;, score=-2164250820.052 total time=   0.8s
# [CV 5/5] END learning_rate=0.2, max_depth=10, n_estimators=100, subsample=0.9;, score=-2316430887.589 total time=   0.7s
# [CV 1/5] END learning_rate=0.2, max_depth=10, n_estimators=150, subsample=0.8;, score=-2160598407.561 total time=   1.0s
# [CV 2/5] END learning_rate=0.2, max_depth=10, n_estimators=150, subsample=0.8;, score=-2419349576.239 total time=   1.1s
# [CV 3/5] END learning_rate=0.2, max_depth=10, n_estimators=150, subsample=0.8;, score=-2345009648.835 total time=   1.0s
# [CV 4/5] END learning_rate=0.2, max_depth=10, n_estimators=150, subsample=0.8;, score=-2158311447.745 total time=   1.1s
# [CV 5/5] END learning_rate=0.2, max_depth=10, n_estimators=150, subsample=0.8;, score=-2284570949.682 total time=   1.1s
# [CV 1/5] END learning_rate=0.2, max_depth=10, n_estimators=150, subsample=0.9;, score=-2201093411.324 total time=   1.0s
# [CV 2/5] END learning_rate=0.2, max_depth=10, n_estimators=150, subsample=0.9;, score=-2415282477.822 total time=   1.2s
# [CV 3/5] END learning_rate=0.2, max_depth=10, n_estimators=150, subsample=0.9;, score=-2397497529.481 total time=   1.0s
# [CV 4/5] END learning_rate=0.2, max_depth=10, n_estimators=150, subsample=0.9;, score=-2158876046.775 total time=   1.1s
# [CV 5/5] END learning_rate=0.2, max_depth=10, n_estimators=150, subsample=0.9;, score=-2309283877.768 total time=   1.1s
# [CV 1/5] END learning_rate=0.2, max_depth=12, n_estimators=100, subsample=0.8;, score=-2244297023.971 total time=   1.9s
# [CV 2/5] END learning_rate=0.2, max_depth=12, n_estimators=100, subsample=0.8;, score=-2574917197.621 total time=   1.8s
# [CV 3/5] END learning_rate=0.2, max_depth=12, n_estimators=100, subsample=0.8;, score=-2436705549.682 total time=   1.7s
# [CV 4/5] END learning_rate=0.2, max_depth=12, n_estimators=100, subsample=0.8;, score=-2269307294.010 total time=   1.8s
# [CV 5/5] END learning_rate=0.2, max_depth=12, n_estimators=100, subsample=0.8;, score=-2384723195.201 total time=   1.9s
# [CV 1/5] END learning_rate=0.2, max_depth=12, n_estimators=100, subsample=0.9;, score=-2327565234.917 total time=   1.8s
# [CV 2/5] END learning_rate=0.2, max_depth=12, n_estimators=100, subsample=0.9;, score=-2483613046.309 total time=   1.9s
# [CV 3/5] END learning_rate=0.2, max_depth=12, n_estimators=100, subsample=0.9;, score=-2514878203.330 total time=   2.0s
# [CV 4/5] END learning_rate=0.2, max_depth=12, n_estimators=100, subsample=0.9;, score=-2238412388.873 total time=   1.9s
# [CV 5/5] END learning_rate=0.2, max_depth=12, n_estimators=100, subsample=0.9;, score=-2413065803.949 total time=   1.9s
# [CV 1/5] END learning_rate=0.2, max_depth=12, n_estimators=150, subsample=0.8;, score=-2243592685.880 total time=   2.6s
# [CV 2/5] END learning_rate=0.2, max_depth=12, n_estimators=150, subsample=0.8;, score=-2572287284.348 total time=   2.6s
# [CV 3/5] END learning_rate=0.2, max_depth=12, n_estimators=150, subsample=0.8;, score=-2436737033.896 total time=   2.7s
# [CV 4/5] END learning_rate=0.2, max_depth=12, n_estimators=150, subsample=0.8;, score=-2268776554.200 total time=   2.7s
# [CV 5/5] END learning_rate=0.2, max_depth=12, n_estimators=150, subsample=0.8;, score=-2384041625.898 total time=   2.6s
# [CV 1/5] END learning_rate=0.2, max_depth=12, n_estimators=150, subsample=0.9;, score=-2326047971.454 total time=   2.6s
# [CV 2/5] END learning_rate=0.2, max_depth=12, n_estimators=150, subsample=0.9;, score=-2483245368.184 total time=   2.7s
# [CV 3/5] END learning_rate=0.2, max_depth=12, n_estimators=150, subsample=0.9;, score=-2514638888.458 total time=   2.7s
# [CV 4/5] END learning_rate=0.2, max_depth=12, n_estimators=150, subsample=0.9;, score=-2239417057.408 total time=   2.8s
# [CV 5/5] END learning_rate=0.2, max_depth=12, n_estimators=150, subsample=0.9;, score=-2413084101.090 total time=   2.6s
# [CV 1/5] END learning_rate=0.2, max_depth=14, n_estimators=100, subsample=0.8;, score=-2315035426.217 total time=   3.1s
# [CV 2/5] END learning_rate=0.2, max_depth=14, n_estimators=100, subsample=0.8;, score=-2603978752.907 total time=   3.1s
# [CV 3/5] END learning_rate=0.2, max_depth=14, n_estimators=100, subsample=0.8;, score=-2537597425.721 total time=   3.2s
# [CV 4/5] END learning_rate=0.2, max_depth=14, n_estimators=100, subsample=0.8;, score=-2369641287.046 total time=   3.4s
# [CV 5/5] END learning_rate=0.2, max_depth=14, n_estimators=100, subsample=0.8;, score=-2501155931.508 total time=   3.4s
# [CV 1/5] END learning_rate=0.2, max_depth=14, n_estimators=100, subsample=0.9;, score=-2460172137.303 total time=   3.4s
# [CV 2/5] END learning_rate=0.2, max_depth=14, n_estimators=100, subsample=0.9;, score=-2611403972.767 total time=   3.4s
# [CV 3/5] END learning_rate=0.2, max_depth=14, n_estimators=100, subsample=0.9;, score=-2559009010.496 total time=   3.8s
# [CV 4/5] END learning_rate=0.2, max_depth=14, n_estimators=100, subsample=0.9;, score=-2295222625.414 total time=   3.6s
# [CV 5/5] END learning_rate=0.2, max_depth=14, n_estimators=100, subsample=0.9;, score=-2449372616.292 total time=   3.4s
# [CV 1/5] END learning_rate=0.2, max_depth=14, n_estimators=150, subsample=0.8;, score=-2315290360.215 total time=   4.5s
# [CV 2/5] END learning_rate=0.2, max_depth=14, n_estimators=150, subsample=0.8;, score=-2604032800.707 total time=   4.5s
# [CV 3/5] END learning_rate=0.2, max_depth=14, n_estimators=150, subsample=0.8;, score=-2537871292.047 total time=   4.8s
# [CV 4/5] END learning_rate=0.2, max_depth=14, n_estimators=150, subsample=0.8;, score=-2369874537.704 total time=   4.8s
# [CV 5/5] END learning_rate=0.2, max_depth=14, n_estimators=150, subsample=0.8;, score=-2500448692.038 total time=   4.9s
# [CV 1/5] END learning_rate=0.2, max_depth=14, n_estimators=150, subsample=0.9;, score=-2459487151.295 total time=   4.7s
# [CV 2/5] END learning_rate=0.2, max_depth=14, n_estimators=150, subsample=0.9;, score=-2610726080.367 total time=   4.6s
# [CV 3/5] END learning_rate=0.2, max_depth=14, n_estimators=150, subsample=0.9;, score=-2558862188.659 total time=   5.0s
# [CV 4/5] END learning_rate=0.2, max_depth=14, n_estimators=150, subsample=0.9;, score=-2294959574.312 total time=   4.9s
# [CV 5/5] END learning_rate=0.2, max_depth=14, n_estimators=150, subsample=0.9;, score=-2448892084.133 total time=   4.8s
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=0.1, ma...
#                                     max_depth=6, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=100,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=None, ...),
#              param_grid={'learning_rate': [0.1, 0.2],
#                          'max_depth': array([ 4,  6,  8, 10, 12, 14]),
#                          'n_estimators': array([100, 150]),
#                          'subsample': [0.8, 0.9]},
#              scoring='neg_mean_squared_error', verbose=6)

# %%
best_xgb = grid_xgb.best_estimator_
best_xgb.fit(X_train_final, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=8, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=150, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# Check scores of this model (RMSE) using (cross_val_score)
mse_scores_xgb_tuned = cross_val_score(estimator=best_xgb, X=X_train_final, y=y_train,
                                 cv=5, scoring='neg_mean_squared_error')
mse_scores_xgb_tuned = mse_scores_xgb_tuned * -1      #we want it positive
rmse_score_xgb_tuned = np.sqrt(mse_scores_xgb_tuned)
print(f"RMSE score using tuned Random Forest --- {np.round(rmse_score_xgb_tuned, 4)}")
print(f"Mean of RMSE score using tuned Random Forest --- {rmse_score_xgb_tuned.mean(): .4f}")

print('****'*30)

# Get prediction using (cross_val_predict)
y_pred_xgb_tuned = cross_val_predict(estimator=best_xgb, X=X_train_final, y=y_train, method='predict', cv=5)

# You can check the (RMSE) using what model predicts and compare it with the mean of above result -- almost the same
# Take care of this point --> don't use .predict when you are using (Cross_Validation)
rmse_pred_xgb_tuned = np.sqrt(mean_squared_error(y_train, y_pred_xgb_tuned))
print(f'RMSE after prediction using tuned Random Forest --- {rmse_pred_xgb_tuned: .4f}')    # almost the same result
# Out:
# RMSE score using tuned Random Forest --- [45156.6241 47290.7814 46324.3726 44948.1235 46516.5659]
# Mean of RMSE score using tuned Random Forest ---  46047.2935
# ************************************************************************************************************************
# RMSE after prediction using tuned Random Forest ---  46055.6158

# %% [markdown]
# ### `Feature Importance using XGBoost`

# %% [markdown]
# > `Feature importance for tunned model of XGBoost`
# * `Importane_types:`
#     * `Weight: the number of times a feature is used to split the data across all trees. --> I used this method`
#     * `gain: The average gain across all splits the feature is used in`
#     * `cover: The average coverage across all splits the feature is used in`
#     * `total_gain: The total gain across all splits the feature is used in`
#     * `total_coverage: The total coverage across all splits the feature is used in`

# %%
# Using XGBoost to get the Feature Importance
# getand sort
feat_import_xgb = best_xgb.get_booster().get_score(importance_type='weight')  # the same as RF, but RF normalize
df_feat_import_xgb = pd.DataFrame.from_dict(feat_import_xgb, orient='index')  # To DF
df_feat_import_xgb = df_feat_import_xgb.reset_index()
df_feat_import_xgb = df_feat_import_xgb.rename({'index': 'Features', 0: 'f_scores'})   # Some Modification

# Taking only the first Numerical 11 cols
df_feat_import_xgb = df_feat_import_xgb[:11]   

# # Some sort to plot
# df_feat_import_xgb['Features'] = num_cols
# #df_feat_import_xgb = df_feat_import_xgb.sort_values(by='f_scores', ascending=False)

# # plotting
# plt.figure(figsize=(12, 8))
# plt.barh(y=df_feat_import_xgb['index'], width=df_feat_import_xgb['0'])
# plt.title('Features Importance using XGBoost Model', fontsize=16, c='k')
# plt.xlabel('f_scores using weight method', fontsize=16, c='k')
# plt.ylabel('Features', fontsize=16, c='k')
# plt.xticks(c='k', fontsize=12)
# plt.yticks(c='k', fontsize=12)
# plt.grid('on')
# plt.show()

# %% [markdown]
# ### `Models Comparison`

# %%
x_x = np.arange(100, 200)  # Random selected points
plt.figure(figsize=(12,8))
plt.plot(x_x,y_train.values[100:200], 'r*-', markersize=7, label='Ground Truth')
plt.plot(x_x,y_pred_tuned_forest[100:200], 'ko--', markersize=7, label='RandomForest')
plt.plot(x_x, y_pred_xgb_tuned[100:200], 'bx-', markersize=7, label='XGBoost')

plt.title('Comparison between models for 100 random points in train DataSet', fontsize=14, c='k')
plt.xlabel('Point Number', fontsize=14, c='k')
plt.ylabel('Prediction (median_house_value)', fontsize=14, c='k')
plt.legend()
plt.grid('on')
plt.show()

# %% [markdown]
# ### `Download the best model -- best_xgb`

# %%
# Download using joblib
joblib.dump(best_xgb, 'model_XGBoost.pkl')
# Out:
# ['model_XGBoost.pkl']

# %%
# to load this pretrained model
loaded_model = joblib.load('model_XGBoost.pkl')

# %% [markdown]
# ### `Inference on Test DataSet`

# %%
# Now we can touch test DataSet using (loaded_model == best_xgb) -- tuned XGBoost Model
y_pred_test = loaded_model.predict(X_test_final)

# %%
np.sqrt(mean_squared_error(y_test, y_pred_test))
# Out:
# 44880.94808999626
